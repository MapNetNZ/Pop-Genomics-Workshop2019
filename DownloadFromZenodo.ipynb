# %% [markdown]
# ## Download bamfiles from Zenodo
#
# February 2019
#
# GOAL
# ----
# - download bamfiles from Zenodo repository 2566534
#
# ----------------
#
# - DOI https://doi.org/10.5281/zenodo.2566534
# - Use the helper app https://gitlab.com/dvolgyes/zenodo_get
# - Next version of the API will include download...coming soon
# - For details of Zenodo upload used to create this see https://gist.github.com/a1f4be666fa8ad8572462d82f6faa57c

# %%
module load conda
conda activate cfljam_MAPNET_POPGEN
# Out:
# (base) (/workspace/appscratch/miniconda/cfljam_MAPNET_POPGEN)
# : 1

# %%
cd bamfiles
# Out:
# (/workspace/appscratch/miniconda/cfljam_MAPNET_POPGEN)
# : 1

# %%
zenodo_get.py  -d 10.5281/zenodo.2566534
# Out:
# Title: MAPNET Population Genomics Workshop Content: Whole genome sequencing of Bactericera cockerelli
# Keywords: Bactericera cockerelli, Genomics, Sequencing, New Zealand, MAPNET
# Publication date: 2019-02-18
# DOI: 10.5281/zenodo.2566534
# Total size: 532.2 MB
#
# Link: https://zenodo.org/api/files/1d0a3dee-a20f-4457-bc5a-1c2022bd028f/season1_trim_C732HANXX-1587-73-25-1_L007_map_190110_2_RG.bam   size: 4.5 MB
# 100% [......................................................] 4698765 / 4698765
# Checksum is correct. (84ec072623111c15e86242c8586d6fe8)
#
# Link: https://zenodo.org/api/files/1d0a3dee-a20f-4457-bc5a-1c2022bd028f/season2_CBR7WANXX-2635-139-25-01_S158_L003_map_190110_2_RG.bam.bai   size: 0.0 MB
# 100% [..............................................................] 848 / 848
# Checksum is correct. (6f1fd85408bc7bf140ab1f4feb65db81)
#
# Link: https://zenodo.org/api/files/1d0a3dee-a20f-4457-bc5a-1c2022bd028f/OG3837_25-01-S62_map_190110_2_RG.bam   size: 2.5 MB
# ...

# %%
ls -lh
# Out:
# total 686M
# -rw-rw-r--. 1 cfljam powerplant  27K Feb 18 23:31 md5sums.txt
# -rw-rw-r--. 1 cfljam powerplant 2.8M Feb 18 23:44 OG3837_25-01-S52_map_190110_2_RG.bam
# -rw-rw-r--. 1 cfljam powerplant  816 Feb 18 23:32 OG3837_25-01-S52_map_190110_2_RG.bam.bai
# -rw-rw-r--. 1 cfljam powerplant 2.8M Feb 18 23:37 OG3837_25-01-S53_map_190110_2_RG.bam
# -rw-rw-r--. 1 cfljam powerplant  784 Feb 18 23:37 OG3837_25-01-S53_map_190110_2_RG.bam.bai
# -rw-rw-r--. 1 cfljam powerplant 2.7M Feb 18 23:39 OG3837_25-01-S54_map_190110_2_RG.bam
# -rw-rw-r--. 1 cfljam powerplant  848 Feb 18 23:44 OG3837_25-01-S54_map_190110_2_RG.bam.bai
# -rw-rw-r--. 1 cfljam powerplant 2.9M Feb 18 23:38 OG3837_25-01-S55_map_190110_2_RG.bam
# -rw-rw-r--. 1 cfljam powerplant  848 Feb 18 23:35 OG3837_25-01-S55_map_190110_2_RG.bam.bai
# -rw-rw-r--. 1 cfljam powerplant 2.9M Feb 18 23:33 OG3837_25-01-S56_map_190110_2_RG.bam
# -rw-rw-r--. 1 cfljam powerplant  816 Feb 18 23:44 OG3837_25-01-S56_map_190110_2_RG.bam.bai
# ...
